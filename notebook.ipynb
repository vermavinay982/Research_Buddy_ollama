# %%
import os
import streamlit as st
from langchain_google_genai import ChatGoogleGenerativeAI, GoogleGenerativeAIEmbeddings

# %%
from langchain.tools
from langchain.chat_models
from langchain.embeddings.base.
from langchain.rate_limiters
from langchain.chat_models.base

# %%
# pip install langchain-text-splitters

# %%
from langchain.chains import (
    create_history_aware_retriever,
    create_retrieval_chain,
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 from langchain.chains import (
#       2     create_history_aware_retriever,
#       3     create_retrieval_chain,
#       4 )
#
# ModuleNotFoundError: No module named 'langchain.chains'

# %%
import langchain 


langchain.__version__
# Out:
# '1.0.3'

# %%
# preferred / direct imports (most stable)
from langchain.chains.conversational_retrieval.base import ConversationalRetrievalChain
from langchain.memory.buffer import ConversationBufferMemory
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # preferred / direct imports (most stable)
# ----> 2 from langchain.chains.conversational_retrieval.base import ConversationalRetrievalChain
#       3 from langchain.memory.buffer import ConversationBufferMemory
#
# ModuleNotFoundError: No module named 'langchain.chains'

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import Chroma
from langchain.chains.conversational_retrieval.base import ConversationalRetrievalChain
from langchain.memory.buffer import ConversationBufferMemory


from langchain.chains import ConversationalRetrievalChain
# from langchain_community.chains import ConversationalRetrievalChain
from langchain.memory import ConversationBufferMemory
from langchain_community.document_loaders import PyPDFLoader
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 3
#       1 from langchain_text_splitters import RecursiveCharacterTextSplitter
#       2 from langchain_community.vectorstores import Chroma
# ----> 3 from langchain.chains.conversational_retrieval.base import ConversationalRetrievalChain
#       4 from langchain.memory.buffer import ConversationBufferMemory
#       7 from langchain.chains import ConversationalRetrievalChain
#
# ModuleNotFoundError: No module named 'langchain.chains'
